# %%
import json

# %%
with open(r'C:\.opdracht3GEC\ORM_validator\EURG-149 json\example.json', 'r') as file:
    data = json.load(file)

# %%
srid = data['srid']

# %%
print(data['common'])
# Out:
# {'id_field': {'objectid': {'sql_type': 'uuid DEFAULT gen_random_uuid()', 'index': 'default', 'pkey': True}}, 'fields': {'country': {'sql_type': 'character varying(8)', 'index': 'default', 'rank': 1}, 'begin_lifespan_version': {'sql_type': 'timestamp without time zone DEFAULT CURRENT_TIMESTAMP', 'rank': 2}, 'end_lifespan_version': {'sql_type': 'timestamp without time zone', 'rank': 3}}, 'working_fields': {'w_national_identifier': {'sql_type': 'character varying(255)', 'rank': 1}, 'w_step': {'sql_type': 'integer', 'index': 'default', 'rank': 2}, 'xy_source': {'sql_type': "character varying(255) DEFAULT 'void_unk'", 'index': 'default', 'rank': 3}, 'z_source': {'sql_type': "character varying(255) DEFAULT 'void_unk'", 'index': 'default', 'rank': 4}, 'w_scale': {'sql_type': "character varying(80) DEFAULT 'void_unk'", 'index': 'default', 'rank': 5}, 'w_release': {'sql_type': 'integer DEFAULT 1', 'index': 'default', 'rank': 6}}}

# %%
dict_text_to_type = {'uuid': 'uuid[notnull]',
                     'timestamp': 'timestamp',
                     'character varying(8)': 'varchar[length(8)]',
                     'character varying(255)': 'varchar[length(255)]',
                     'character varying(80)': 'varchar[length(80)]',
                     'integer': 'int4',
                     'jsonb': 'jsonb',
                     'geometry(LineStringZ,${srid})': f'LineStringZ[srid({srid})]',
                     'geometry(LineString,${srid})': f'LineString[srid({srid})]',
                     'geometry(MultiLineStringZ,${srid})': f'MultiLineStringZ[srid({srid})]',
                     'geometry(MultiLineString,${srid})': f'MultiLineString[srid({srid})]',
                     'geometry(PointZ,${srid})': f'PointZ[srid({srid})]',
                     'geometry(Point,${srid})': f'Point[srid({srid})]',
                     'geometry(MultiPolygonZ,${srid})': f'MultiPolygonZ[srid({srid})]',
                     'geometry(MultiPolygon,${srid})': f'MultiPolygon[srid({srid})]',                
                     }
# Out:
# srid
# common
# work
# working_ids
# history
# themes

# %%
common_part = []

for x in data['common']:
    for y in data['common'][x]:
        attribute_name = y
 
        attribute_type_text = data['common'][x][y]['sql_type'].split('DEFAULT')[0].split('without')[0].strip()
        attribute_type = dict_text_to_type[attribute_type_text]
 
        common_part.append(f"{attribute_name}: {attribute_type}")
        
print(common_part)
# Out:
# ['objectid: uuid[notnull]', 'country: varchar[length(8)]', 'begin_lifespan_version: timestamp', 'end_lifespan_version: timestamp', 'w_national_identifier: varchar[length(255)]', 'w_step: int4', 'xy_source: varchar[length(255)]', 'z_source: varchar[length(255)]', 'w_scale: varchar[length(80)]', 'w_release: int4']

# %%
dict_theme_to_tables = {}

for x in data['themes']:
    dict_table_to_class_attributes = {}

    for y in data['themes'][x]['tables']:
        theme_part = []
        for z in data['themes'][x]['tables'][y]['fields']:
            attribute_name = z
            attribute_type_text = data['themes'][x]['tables'][y]['fields'][z]['sql_type'].split('DEFAULT')[0].split('without')[0].strip()
            attribute_type = dict_text_to_type[attribute_type_text]
            theme_part.append(f"{attribute_name}: {attribute_type}")
        dict_table_to_class_attributes[y] = common_part + theme_part
    
    dict_theme_to_tables[x] = dict_table_to_class_attributes

# %%
dict_theme_to_tables
# Out:
# {'tn': {'road_link': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: LineStringZ[srid(3035)]',
#    'form_of_way: varchar[length(255)]',
#    'functional_road_class: varchar[length(255)]',
#    'number_of_lanes: varchar[length(255)]',
#    'vertical_position: varchar[length(255)]',
#    'vertical_level: varchar[length(255)]',
#    'tent_network: varchar[length(255)]',
#    'street_name: jsonb',
#    'street_label: varchar[length(255)]',
#    'road_surface_category: varchar[length(255)]',
#    'traffic_flow_direction: varchar[length(255)]',
#    'access_restriction: varchar[length(255)]',
#    'restriction_for_vehicles: jsonb',
#    'speed_limit: varchar[length(255)]',
#    'condition_of_facility: varchar[length(255)]',
#    'link_to_road: varchar[length(255)]',
#    'road_national_road_code: varchar[length(255)]',
#    'road_european_route_number: varchar[length(255)]',
#    'road_name: jsonb',
#    'road_label: varchar[length(255)]'],
#   'road': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiLineStringZ[srid(3035)]',
#    'national_road_code: varchar[length(255)]',
#    'european_route_number: varchar[length(255)]',
#    'road_name: jsonb',
#    'road_label: varchar[length(255)]'],
#   'road_node': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: PointZ[srid(3035)]',
#    'local_name: varchar[length(255)]',
#    'form_of_road_node: varchar[length(255)]'],
#   'road_service_area': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'type: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'road_service_point': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: PointZ[srid(3035)]',
#    'type: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'marker_post': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: PointZ[srid(3035)]',
#    'link_to_road: varchar[length(255)]',
#    'code: varchar[length(255)]',
#    'distance: varchar[length(255)]',
#    'w_link_to_national_road: varchar[length(255)]'],
#   'railway_link': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: LineStringZ[srid(3035)]',
#    'type: varchar[length(255)]',
#    'number_of_tracks: varchar[length(255)]',
#    'vertical_position: varchar[length(255)]',
#    'vertical_level: varchar[length(255)]',
#    'tent_network: varchar[length(255)]',
#    'electrified: varchar[length(255)]',
#    'condition_of_facility: varchar[length(255)]',
#    'railway_line_code: varchar[length(255)]',
#    'railway_line_name: jsonb',
#    'railway_line_label: varchar[length(255)]',
#    'min_max_track: varchar[length(255)]',
#    'nominal_track_gauge: varchar[length(255)]',
#    'track_gauge_category: varchar[length(255)]',
#    'speed_class: varchar[length(255)]',
#    'railway_use: varchar[length(255)]',
#    'access_restriction: varchar[length(255)]'],
#   'railway_line': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiLineStringZ[srid(3035)]',
#    'railway_line_code: varchar[length(255)]',
#    'railway_line_name: jsonb',
#    'railway_line_label: varchar[length(255)]'],
#   'railway_station_area': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'station_code: varchar[length(255)]',
#    'railway_use: varchar[length(255)]',
#    'form_of_railway_station: varchar[length(255)]'],
#   'railway_station_point': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: PointZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'station_code: varchar[length(255)]',
#    'railway_use: varchar[length(255)]',
#    'form_of_railway_station: varchar[length(255)]'],
#   'aerodrome_point': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: PointZ[srid(3035)]',
#    'designator_iata: varchar[length(255)]',
#    'location_indicator_icao: varchar[length(255)]',
#    'un_locode: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'aerodrome_category: varchar[length(255)]',
#    'aerodrome_type: varchar[length(255)]',
#    'use_restriction: varchar[length(255)]',
#    'condition_of_facility: varchar[length(255)]'],
#   'aerodrome_area': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'designator_iata: varchar[length(255)]',
#    'location_indicator_icao: varchar[length(255)]',
#    'un_locode: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'aerodrome_category: varchar[length(255)]',
#    'aerodrome_type: varchar[length(255)]',
#    'use_restriction: varchar[length(255)]',
#    'condition_of_facility: varchar[length(255)]'],
#   'runway_area': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'surface_composition: varchar[length(255)]'],
#   'runway_line': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiLineStringZ[srid(3035)]',
#    'surface_composition: varchar[length(255)]'],
#   'ferry_crossing': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiLineStringZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'ferry_use: varchar[length(255)]',
#    'tent_network: varchar[length(255)]',
#    'access_restriction: varchar[length(255)]'],
#   'port_area': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'un_locode: varchar[length(255)]',
#    'tent_network: varchar[length(255)]'],
#   'port_point': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: PointZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'un_locode: varchar[length(255)]',
#    'tent_network: varchar[length(255)]']},
#  'ib': {'international_boundary_line': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: LineString[srid(3035)]',
#    'boundary_type: varchar[length(255)]',
#    'legal_status: varchar[length(255)]',
#    'technical_status: varchar[length(255)]',
#    'boundary_source: varchar[length(255)]'],
#   'international_boundary_node': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: Point[srid(3035)]',
#    'legal_status: varchar[length(255)]',
#    'technical_status: varchar[length(255)]'],
#   'landmask': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygon[srid(3035)]']},
#  'au': {'administrative_boundary': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: LineString[srid(3035)]',
#    'national_level: varchar[length(255)]',
#    'legal_status: varchar[length(255)]',
#    'technical_status: varchar[length(255)]'],
#   'administrative_unit_area_1': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygon[srid(3035)]',
#    'national_code: varchar[length(255)]',
#    'shn: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'national_level_code: varchar[length(255)]',
#    'link_to_residence_of_authority: varchar[length(255)]',
#    'land_cover_type: varchar[length(255)]',
#    'valid_from: timestamp',
#    'valid_to: timestamp'],
#   'administrative_unit_area_2': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygon[srid(3035)]',
#    'national_code: varchar[length(255)]',
#    'shn: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'national_level_code: varchar[length(255)]',
#    'link_to_residence_of_authority: varchar[length(255)]',
#    'land_cover_type: varchar[length(255)]',
#    'valid_from: timestamp',
#    'valid_to: timestamp'],
#   'administrative_unit_area_3': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygon[srid(3035)]',
#    'national_code: varchar[length(255)]',
#    'shn: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'national_level_code: varchar[length(255)]',
#    'link_to_residence_of_authority: varchar[length(255)]',
#    'land_cover_type: varchar[length(255)]',
#    'valid_from: timestamp',
#    'valid_to: timestamp'],
#   'administrative_unit_area_4': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygon[srid(3035)]',
#    'national_code: varchar[length(255)]',
#    'shn: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'national_level_code: varchar[length(255)]',
#    'link_to_residence_of_authority: varchar[length(255)]',
#    'land_cover_type: varchar[length(255)]',
#    'valid_from: timestamp',
#    'valid_to: timestamp'],
#   'administrative_unit_area_5': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygon[srid(3035)]',
#    'national_code: varchar[length(255)]',
#    'shn: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'national_level_code: varchar[length(255)]',
#    'link_to_residence_of_authority: varchar[length(255)]',
#    'land_cover_type: varchar[length(255)]',
#    'valid_from: timestamp',
#    'valid_to: timestamp'],
#   'administrative_unit_area_6': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygon[srid(3035)]',
#    'national_code: varchar[length(255)]',
#    'shn: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'national_level_code: varchar[length(255)]',
#    'link_to_residence_of_authority: varchar[length(255)]',
#    'land_cover_type: varchar[length(255)]',
#    'valid_from: timestamp',
#    'valid_to: timestamp'],
#   'administrative_hierarchy': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'national_level: varchar[length(255)]',
#    'national_level_name: jsonb',
#    'national_level_label: varchar[length(255)]',
#    'national_level_code: varchar[length(255)]',
#    'shn_digit: int4'],
#   'maritime_zone': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygon[srid(3035)]',
#    'national_code: varchar[length(255)]',
#    'shn: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'national_level_code: varchar[length(255)]',
#    'zone_type: varchar[length(255)]'],
#   'residence_of_authority': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: PointZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]']},
#  'hy': {'watercourse_link': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: LineStringZ[srid(3035)]',
#    'level: varchar[length(255)]',
#    'persistence: varchar[length(255)]',
#    'tidal: varchar[length(255)]',
#    'flow_direction: varchar[length(255)]',
#    'stream_order: varchar[length(255)]',
#    'hydro_identifier: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'origin: varchar[length(255)]',
#    'fictitious: varchar[length(255)]',
#    'tent_network: varchar[length(255)]',
#    'cemt_class: varchar[length(255)]',
#    'navigable: varchar[length(255)]',
#    'width_lower_range: varchar[length(255)]',
#    'width_upper_range: varchar[length(255)]'],
#   'watercourse': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiLineStringZ[srid(3035)]',
#    'hydro_identifier: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'hydro_node': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: PointZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'hydro_node_category: varchar[length(255)]'],
#   'watercourse_area': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'persistence: varchar[length(255)]',
#    'tidal: varchar[length(255)]',
#    'origin: varchar[length(255)]',
#    'hydro_identifier: varchar[length(255)]'],
#   'standing_water': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'persistence: varchar[length(255)]',
#    'tidal: varchar[length(255)]',
#    'origin: varchar[length(255)]',
#    'hydro_identifier: varchar[length(255)]'],
#   'drainage_basin': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygon[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]',
#    'hydro_identifier: varchar[length(255)]',
#    'basin_order: varchar[length(255)]'],
#   'shoreline': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: LineStringZ[srid(3035)]',
#    'water_level: varchar[length(255)]',
#    'origin: varchar[length(255)]'],
#   'shore': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'composition: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'dam_area': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'hydro_identifier: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'dam_line': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiLineStringZ[srid(3035)]',
#    'hydro_identifier: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'dam_point': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: PointZ[srid(3035)]',
#    'hydro_identifier: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'lock_area': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'hydro_identifier: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'lock_line': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiLineStringZ[srid(3035)]',
#    'hydro_identifier: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'lock_point': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: PointZ[srid(3035)]',
#    'hydro_identifier: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'falls_area': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'falls_line': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiLineStringZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'falls_point': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: PointZ[srid(3035)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'glacier_snowfield': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'ice_area_type: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'wetland': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'local_name: varchar[length(255)]',
#    'tidal: varchar[length(255)]'],
#   'shoreline_construction_area': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: MultiPolygonZ[srid(3035)]',
#    'shoreline_construction_type: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]'],
#   'shoreline_construction_line': ['objectid: uuid[notnull]',
#    'country: varchar[length(8)]',
#    'begin_lifespan_version: timestamp',
#    'end_lifespan_version: timestamp',
#    'w_national_identifier: varchar[length(255)]',
#    'w_step: int4',
#    'xy_source: varchar[length(255)]',
#    'z_source: varchar[length(255)]',
#    'w_scale: varchar[length(80)]',
#    'w_release: int4',
#    'geom: LineStringZ[srid(3035)]',
#    'shoreline_construction_type: varchar[length(255)]',
#    'name: jsonb',
#    'label: varchar[length(255)]']}}

# %%
for theme in dict_theme_to_tables:
    string_for_theme = ""
    for table in dict_theme_to_tables[theme]:
        string_for_table = f"class {table}(feature): \n"
        list_of_attributes = dict_theme_to_tables[theme][table]
        for attribute in list_of_attributes:
            string_for_table += f"\t{attribute} \n"
        print(string_for_table)
# Out:
# class road_link(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: LineStringZ[srid(3035)]
# 	form_of_way: varchar[length(255)]
# 	functional_road_class: varchar[length(255)]
# 	number_of_lanes: varchar[length(255)]
# 	vertical_position: varchar[length(255)]
# 	vertical_level: varchar[length(255)]
# 	tent_network: varchar[length(255)]
# 	street_name: jsonb
# 	street_label: varchar[length(255)]
# 	road_surface_category: varchar[length(255)]
# 	traffic_flow_direction: varchar[length(255)]
# 	access_restriction: varchar[length(255)]
# 	restriction_for_vehicles: jsonb
# 	speed_limit: varchar[length(255)]
# 	condition_of_facility: varchar[length(255)]
# 	link_to_road: varchar[length(255)]
# 	road_national_road_code: varchar[length(255)]
# 	road_european_route_number: varchar[length(255)]
# 	road_name: jsonb
# 	road_label: varchar[length(255)]
#
# class road(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiLineStringZ[srid(3035)]
# 	national_road_code: varchar[length(255)]
# 	european_route_number: varchar[length(255)]
# 	road_name: jsonb
# 	road_label: varchar[length(255)]
#
# class road_node(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: PointZ[srid(3035)]
# 	local_name: varchar[length(255)]
# 	form_of_road_node: varchar[length(255)]
#
# class road_service_area(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	type: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class road_service_point(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: PointZ[srid(3035)]
# 	type: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class marker_post(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: PointZ[srid(3035)]
# 	link_to_road: varchar[length(255)]
# 	code: varchar[length(255)]
# 	distance: varchar[length(255)]
# 	w_link_to_national_road: varchar[length(255)]
#
# class railway_link(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: LineStringZ[srid(3035)]
# 	type: varchar[length(255)]
# 	number_of_tracks: varchar[length(255)]
# 	vertical_position: varchar[length(255)]
# 	vertical_level: varchar[length(255)]
# 	tent_network: varchar[length(255)]
# 	electrified: varchar[length(255)]
# 	condition_of_facility: varchar[length(255)]
# 	railway_line_code: varchar[length(255)]
# 	railway_line_name: jsonb
# 	railway_line_label: varchar[length(255)]
# 	min_max_track: varchar[length(255)]
# 	nominal_track_gauge: varchar[length(255)]
# 	track_gauge_category: varchar[length(255)]
# 	speed_class: varchar[length(255)]
# 	railway_use: varchar[length(255)]
# 	access_restriction: varchar[length(255)]
#
# class railway_line(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiLineStringZ[srid(3035)]
# 	railway_line_code: varchar[length(255)]
# 	railway_line_name: jsonb
# 	railway_line_label: varchar[length(255)]
#
# class railway_station_area(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	station_code: varchar[length(255)]
# 	railway_use: varchar[length(255)]
# 	form_of_railway_station: varchar[length(255)]
#
# class railway_station_point(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: PointZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	station_code: varchar[length(255)]
# 	railway_use: varchar[length(255)]
# 	form_of_railway_station: varchar[length(255)]
#
# class aerodrome_point(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: PointZ[srid(3035)]
# 	designator_iata: varchar[length(255)]
# 	location_indicator_icao: varchar[length(255)]
# 	un_locode: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	aerodrome_category: varchar[length(255)]
# 	aerodrome_type: varchar[length(255)]
# 	use_restriction: varchar[length(255)]
# 	condition_of_facility: varchar[length(255)]
#
# class aerodrome_area(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	designator_iata: varchar[length(255)]
# 	location_indicator_icao: varchar[length(255)]
# 	un_locode: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	aerodrome_category: varchar[length(255)]
# 	aerodrome_type: varchar[length(255)]
# 	use_restriction: varchar[length(255)]
# 	condition_of_facility: varchar[length(255)]
#
# class runway_area(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	surface_composition: varchar[length(255)]
#
# class runway_line(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiLineStringZ[srid(3035)]
# 	surface_composition: varchar[length(255)]
#
# class ferry_crossing(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiLineStringZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	ferry_use: varchar[length(255)]
# 	tent_network: varchar[length(255)]
# 	access_restriction: varchar[length(255)]
#
# class port_area(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	un_locode: varchar[length(255)]
# 	tent_network: varchar[length(255)]
#
# class port_point(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: PointZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	un_locode: varchar[length(255)]
# 	tent_network: varchar[length(255)]
#
# class international_boundary_line(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: LineString[srid(3035)]
# 	boundary_type: varchar[length(255)]
# 	legal_status: varchar[length(255)]
# 	technical_status: varchar[length(255)]
# 	boundary_source: varchar[length(255)]
#
# class international_boundary_node(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: Point[srid(3035)]
# 	legal_status: varchar[length(255)]
# 	technical_status: varchar[length(255)]
#
# class landmask(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygon[srid(3035)]
#
# class administrative_boundary(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: LineString[srid(3035)]
# 	national_level: varchar[length(255)]
# 	legal_status: varchar[length(255)]
# 	technical_status: varchar[length(255)]
#
# class administrative_unit_area_1(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygon[srid(3035)]
# 	national_code: varchar[length(255)]
# 	shn: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	national_level_code: varchar[length(255)]
# 	link_to_residence_of_authority: varchar[length(255)]
# 	land_cover_type: varchar[length(255)]
# 	valid_from: timestamp
# 	valid_to: timestamp
#
# class administrative_unit_area_2(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygon[srid(3035)]
# 	national_code: varchar[length(255)]
# 	shn: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	national_level_code: varchar[length(255)]
# 	link_to_residence_of_authority: varchar[length(255)]
# 	land_cover_type: varchar[length(255)]
# 	valid_from: timestamp
# 	valid_to: timestamp
#
# class administrative_unit_area_3(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygon[srid(3035)]
# 	national_code: varchar[length(255)]
# 	shn: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	national_level_code: varchar[length(255)]
# 	link_to_residence_of_authority: varchar[length(255)]
# 	land_cover_type: varchar[length(255)]
# 	valid_from: timestamp
# 	valid_to: timestamp
#
# class administrative_unit_area_4(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygon[srid(3035)]
# 	national_code: varchar[length(255)]
# 	shn: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	national_level_code: varchar[length(255)]
# 	link_to_residence_of_authority: varchar[length(255)]
# 	land_cover_type: varchar[length(255)]
# 	valid_from: timestamp
# 	valid_to: timestamp
#
# class administrative_unit_area_5(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygon[srid(3035)]
# 	national_code: varchar[length(255)]
# 	shn: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	national_level_code: varchar[length(255)]
# 	link_to_residence_of_authority: varchar[length(255)]
# 	land_cover_type: varchar[length(255)]
# 	valid_from: timestamp
# 	valid_to: timestamp
#
# class administrative_unit_area_6(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygon[srid(3035)]
# 	national_code: varchar[length(255)]
# 	shn: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	national_level_code: varchar[length(255)]
# 	link_to_residence_of_authority: varchar[length(255)]
# 	land_cover_type: varchar[length(255)]
# 	valid_from: timestamp
# 	valid_to: timestamp
#
# class administrative_hierarchy(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	national_level: varchar[length(255)]
# 	national_level_name: jsonb
# 	national_level_label: varchar[length(255)]
# 	national_level_code: varchar[length(255)]
# 	shn_digit: int4
#
# class maritime_zone(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygon[srid(3035)]
# 	national_code: varchar[length(255)]
# 	shn: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	national_level_code: varchar[length(255)]
# 	zone_type: varchar[length(255)]
#
# class residence_of_authority(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: PointZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class watercourse_link(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: LineStringZ[srid(3035)]
# 	level: varchar[length(255)]
# 	persistence: varchar[length(255)]
# 	tidal: varchar[length(255)]
# 	flow_direction: varchar[length(255)]
# 	stream_order: varchar[length(255)]
# 	hydro_identifier: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	origin: varchar[length(255)]
# 	fictitious: varchar[length(255)]
# 	tent_network: varchar[length(255)]
# 	cemt_class: varchar[length(255)]
# 	navigable: varchar[length(255)]
# 	width_lower_range: varchar[length(255)]
# 	width_upper_range: varchar[length(255)]
#
# class watercourse(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiLineStringZ[srid(3035)]
# 	hydro_identifier: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class hydro_node(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: PointZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	hydro_node_category: varchar[length(255)]
#
# class watercourse_area(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	persistence: varchar[length(255)]
# 	tidal: varchar[length(255)]
# 	origin: varchar[length(255)]
# 	hydro_identifier: varchar[length(255)]
#
# class standing_water(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	persistence: varchar[length(255)]
# 	tidal: varchar[length(255)]
# 	origin: varchar[length(255)]
# 	hydro_identifier: varchar[length(255)]
#
# class drainage_basin(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygon[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
# 	hydro_identifier: varchar[length(255)]
# 	basin_order: varchar[length(255)]
#
# class shoreline(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: LineStringZ[srid(3035)]
# 	water_level: varchar[length(255)]
# 	origin: varchar[length(255)]
#
# class shore(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	composition: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class dam_area(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	hydro_identifier: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class dam_line(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiLineStringZ[srid(3035)]
# 	hydro_identifier: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class dam_point(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: PointZ[srid(3035)]
# 	hydro_identifier: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class lock_area(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	hydro_identifier: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class lock_line(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiLineStringZ[srid(3035)]
# 	hydro_identifier: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class lock_point(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: PointZ[srid(3035)]
# 	hydro_identifier: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class falls_area(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class falls_line(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiLineStringZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class falls_point(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: PointZ[srid(3035)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class glacier_snowfield(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	ice_area_type: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class wetland(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	local_name: varchar[length(255)]
# 	tidal: varchar[length(255)]
#
# class shoreline_construction_area(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: MultiPolygonZ[srid(3035)]
# 	shoreline_construction_type: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
#
# class shoreline_construction_line(feature):
# 	objectid: uuid[notnull]
# 	country: varchar[length(8)]
# 	begin_lifespan_version: timestamp
# 	end_lifespan_version: timestamp
# 	w_national_identifier: varchar[length(255)]
# 	w_step: int4
# 	xy_source: varchar[length(255)]
# 	z_source: varchar[length(255)]
# 	w_scale: varchar[length(80)]
# 	w_release: int4
# 	geom: LineStringZ[srid(3035)]
# 	shoreline_construction_type: varchar[length(255)]
# 	name: jsonb
# 	label: varchar[length(255)]
